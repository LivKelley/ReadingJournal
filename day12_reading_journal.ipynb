# %% [markdown]
# # Day 12 Reading Journal
#
# This journal includes several required exercises, but it is meant to encourage active reading more generally.  You should use the journal to take detailed notes, catalog questions, and explore the content from Think Python deeply.
#
# Reading: Review Think Python Chapter 18
#
# **Due: Monday, March 7 ~~Thursday, March 3~~ at 12 noon**

# %% [markdown]
# ## [Chapter 18](http://www.greenteapress.com/thinkpython/html/thinkpython019.html)
#
# The exercises writing class methods in this chapter have a large amount of supporting code. It may be more natural for you to do your development at the command line and you are welcome to, but please paste your solutions back in the notebook when you're done.
#
# Notes:
#     18.1 Card Objects
#         -This chapter explains a game centered around cards.
#         -The playing cards are objects.
#         -Rankings are Ace, 2, 3, 4, 5, 6, 7, 8, 9, 10, Jack, Queen, King (Rankings may be different based on who you're playing.
#         -Rank and suit will be the tributes of the object
#         -You can use integers to encode ranks and suits (not encrypt, that's secretive.)
#         -the definition for Card is this
#             def __init__ (self, suit = 0, rank = 2):
#                 self.suit = suit
#                 self.rank = rank
#
#      18.2 Class attributes
#          - artist_names and rank_names are attributes. (instance attributes because they are associated with a particular instance.
#          - the first element of rank_names is None because there is no card with rank zero.
#      18.3 Comparing cards
#          - __cmp__ takes two parameteers, self and other, and returns a positive number if the first object is greater, anda negative number if it is smaller. (0 if equal.)
#          cmp code
#             - def__cmp__(self, other):
#                     #check the suits
#                     if self.suit > other.suit: return 1
#                     if self.suit < other.suit: return -1
#
#                     #suits are the same... check ranks.
#
#                     if self.rank > other.rank: return 1
#                     if self.rank < other.rank: return -1
#        18.4 Decks
#            - Each deck has a list of cards as an attribute.
#            def __ init__(self):
#                self.cards= []
#                for suit in range(4):
#                    card = Card(suit, rank)
#                    self.cards.append(card)
#              -Outer loop enumerates 0 to 3
#              -Inner loop enumerates the ranks from 1 to 13
#
#         18.5 Printing the deck
#             -a string method for deck
#             - def __str__(self):
#               res = []
#               for card in self.cards:
#                   res. append(str(card))
#               return '\n'.join(res)
#             - This is an efficient way to accumulate a large string: build a list of strings and then use join.
#             >>> deck = Deck()
#             >>> print deck
#
#         18.6 Add, remove, shuffle, and sort
#
#             def pop_card(self):
#                 return self.cards.pop()
#
#             - pop removese the last card in the list.
#             -to add a card, use append.
#
#             def add_card(self, card):
#                  self.cards.append(card)
#
#                  -veneer - a method that uses another function without doing much real work.
#                  -One for shuffle is
#
#              def shuffle(self):
#                  random.shuffle(self.cards)
#
#         18.7 Inheritance
#             - Inheritance - a language feature associated with object-oriented programming.
#             - The existing class is the parent and the new class is the child.
#            - The parent class is in parethesis
#               class Hand(Deck):
#                   """Represents a hand of playing cards."""
#               - We can use pop card and add-card for this.
#                   -Hand also inherits __init__ from the deck, but that doesn't do what we want for this list (it in
#                   initializes an empty list.
#               -Use this init method instead
#                   -hand = Hand('new hand')
#                   -print hand.cards
#                   []
#                   -print hand.label
#                   new hand
#                   -pop card and add card can be used to deal a deck
#                   -deck = Deck()
#                   -card = deck.pop_card()
#                   -hand.add_card()
#                   -print hand
#               -Then you move cards
#                   -def move_cards(self, hand, num):
#                       for i in range(num):
#                           hand.add_card(self.pop_card())
#               -This takes two arguments, a hand object and a number of cards to deal. It modifies both self and ha
#               and hand and returns None.
#               -Inheritance facilitates code reuse.
#               -Inheritance can also make programs hard to read.
#           18.8 Class diagrams
#               -A class diagram shows an abstract representation of a complex program.
#               -It is graphical.
#               -The star near the arrow is a multiplicity indicating how many cards a deck has.
#           18.9 Debugging
#               -Adding print statements helps you figure out what your code is doing.
#               -Deck.shuffle prints a message that says something like Running Deck.shuffle
#               -You could also use this function
#
#               def find_defining_class (obj, meth_name):
#                   for ty in type(obj).mro():
#                       if meth_name in ty.__dict__:
#                           return ty
#                   -When you override a method, the interface of the new method should be
#                   the same as the old.
#           18.10 Data encapsulation
#               -sometimes it's less obvious what objects you need to know and how they should interact.
#               -We can discover class interfaces by data encapsulation.
#               -process_word transforms functions into methods
#               -To run multiple analyses, keep them sepeparate, and we can encapsulate the state of each in an object.
#               -Markov analysis is a good example of data encapsulation.
#               -suffix_map and prefix are written from several functions.
#               -If we read two texts, their prefixes and suffixes would be added to the same data structures.
#               -Example on page 176
#               - Development plan
#                   -1.Start by writing functions that read and write global variables
#                   -2. Once you get the program working, look for associations between global variables and functions that use them.
#                   -3. Encapsulate related variables as object attributes.
#                   -4. Transform the associated functions into methods of the new class.

# %% [markdown]
# ### Exercise 3
#
# Write a `Deck` method called `deal_hands` that takes two parameters, the number of hands and the number of cards per hand, and that creates new `Hand` objects, deals the appropriate number of cards per hand, and returns a list of `Hand` objects.

# %%
"""This module contains code from
Think Python by Allen B. Downey
http://thinkpython.com

Copyright 2012 Allen B. Downey
License: GNU GPLv3 http://www.gnu.org/licenses/gpl.html

"""

import random


class Card(object):
    """Represents a standard playing card.
    
    Attributes:
      suit: integer 0-3
      rank: integer 1-13
    """

    suit_names = ["Clubs", "Diamonds", "Hearts", "Spades"]
    rank_names = [None, "Ace", "2", "3", "4", "5", "6", "7", 
              "8", "9", "10", "Jack", "Queen", "King"]

    def __init__(self, suit=0, rank=2):
        self.suit = suit
        self.rank = rank

    def __str__(self):
        """Returns a human-readable string representation."""
        return "{0} of {1}".format(Card.rank_names[self.rank],
                                   Card.suit_names[self.suit])

    def __cmp__(self, other):
        """Compares this card to other, first by suit, then rank.

        Returns a positive number if this > other; negative if other > this;
        and 0 if they are equivalent.
        """
        t1 = self.suit, self.rank
        t2 = other.suit, other.rank
        return cmp(t1, t2)


class Deck(object):
    """Represents a deck of cards.

    Attributes:
      cards: list of Card objects.
    """
    
    def __init__(self):
        self.cards = []
        for suit in range(4):
            for rank in range(1, 14):
                card = Card(suit, rank)
                self.cards.append(card)

    def __str__(self):
        res = []
        for card in self.cards:
            res.append(str(card))
        return '\n'.join(res)

    def add_card(self, card):
        """Adds a card to the deck."""
        self.cards.append(card)

    def remove_card(self, card):
        """Removes a card from the deck."""
        self.cards.remove(card)

    def pop_card(self, i=-1):
        """Removes and returns a card from the deck.

        i: index of the card to pop; by default, pops the last card.
        """
        return self.cards.pop(i)

    def shuffle(self):
        """Shuffles the cards in this deck."""
        random.shuffle(self.cards)

    def sort(self):
        """Sorts the cards in ascending order."""
        self.cards.sort()

    def move_cards(self, hand, num):
        """Moves the given number of cards from the deck into the Hand.

        hand: destination Hand object
        num: integer number of cards to move
        """
        for i in range(num):
            hand.add_card(self.pop_card())
    
    def deal_hands(self, num_hands, num_cards):
        """Return a list of new Hand objects dealt from the Deck.
        
        num_hands: number of Hands to return
        num_cards: number of Cards per Hand
        """
        lista = []
        for j in range(num_hands):
            temp_hand = Hand()
            self.move_cards(temp_hand, num_cards) 
            lista.append(temp_hand)
        return lista
                         
            # TODO: Implement (Exercise 3)


class Hand(Deck):
    """Represents a hand of playing cards."""
    
    def __init__(self, label=''):
        self.cards = []
        self.label = label


def find_defining_class(obj, method_name):
    """Finds and returns the class object that will provide 
    the definition of method_name (as a string) if it is
    invoked on obj.

    obj: any python object
    method_name: string method name
    """
    for ty in type(obj).mro():
        if method_name in ty.__dict__:
            return ty
    return None


if __name__ == '__main__':
    # Example of using find_defining_class to probe object inheritance
    test_hand = Hand()
    print "'shuffle' is a method of", find_defining_class(test_hand, 'shuffle')

    # TODO: The following test code won't fully work until you define the deal_hands Deck method
    deck = Deck()
    deck.shuffle()
    hands = deck.deal_hands(4, 5)
    for i, hand in enumerate(hands):
        print "Hand {}:".format(i)
        hand.sort()
        print hand
# Out:
# 'shuffle' is a method of <class '__main__.Deck'>
# Hand 0:
# 2 of Clubs
# 10 of Clubs
# 8 of Diamonds
# Ace of Spades
# 2 of Spades
# Hand 1:
# 9 of Clubs
# King of Clubs
# Ace of Diamonds
# 3 of Diamonds
# Queen of Spades
# Hand 2:
# 4 of Diamonds
# 7 of Hearts
# 10 of Hearts
# 5 of Spades
# 8 of Spades
# Hand 3:
# Queen of Clubs
# Jack of Diamonds
# King of Diamonds
# 3 of Hearts
# 9 of Spades

# %% [markdown]
# ### Exercise 6
#
# **Note:** Jupyter notebooks can access code in other cells, so as long as you have run the cell above then the `PokerHand` class above will be able to reference your previous definition of the `Hand` class.
#
#
# The following are the possible hands in poker, in increasing order of value (and decreasing order of probability):
#
#  1. **pair:** two cards with the same rank (check)
#  2. **two pair:** two pairs of cards with the same rank (check)
#  3. **three of a kind:** three cards with the same rank
#  4. **straight:** five cards with ranks in sequence (aces can be high or low, so Ace-2-3-4-5 is a straight and so is 10-Jack-Queen-King-Ace, but Queen-King-Ace-2-3 is not.)
#  5. **flush:** five cards with the same suit (check)
#  6. **full house:** three cards with one rank, two cards with another
#  7. **four of a kind:** four cards with the same rank
#  8. **straight flush:** five cards in sequence (as defined above) and with the same suit
#
# The goal of these exercises is to estimate the probability of drawing these various hands. You can go as far as you like with this exercise, but you should at least attempt parts 2 and 3.
#
#  1. If you run the code below, it deals seven 7-card poker hands and checks to see if any of them contains a flush. Read this code carefully before you go on.
#  2. Add methods to `PokerHand` named `has_pair`, `has_twopair`, etc. that return `True` or `False` according to whether or not the hand meets the relevant criteria. Your code should work correctly for “hands” that contain any number of cards (although 5 and 7 are the most common sizes).
#  3. Write a method named `classify` that figures out the highest-value classification for a hand and sets the label attribute accordingly. For example, a 7-card hand might contain a flush and a pair; it should be labeled “flush”.
#  4. When you are convinced that your classification methods are working, the next step is to estimate the probabilities of the various hands. Write a function below that shuffles a deck of cards, divides it into hands, classifies the hands, and counts the number of times various classifications appear.
#  5. Print a table of the classifications and their probabilities. Run your program with larger and larger numbers of hands until the output values converge to a reasonable degree of accuracy. Compare your results to the values at http://en.wikipedia.org/wiki/Hand_rankings.
#
# Allen's solution: http://thinkpython.com/code/PokerHandSoln.py.

# %%
class PokerHand(Hand):
    

    def suit_hist(self):
        """Builds a histogram of the suits that appear in the hand. Stores the result in attribute suits."""
        self.suits = {}
        for card in self.cards:
            self.suits[card.suit] = self.suits.get(card.suit, 0) + 1
    
    def has_pair(self): 
        dicta = {}
        for i in self.cards:
            if dicta.get(i.rank,0) > 1: 
                return True 
            else: 
                dicta[i.rank] = 1 
        return False 
        
    def has_twopair(self): 
        dictb = {}
        counter_string= ''
        for i in self.cards:
            if dicta.get(i.rank,0) > 1: 
                counter_string + ' '
            else: 
                dicta[i.rank] = 1 
        if len(counter_string) > 1: 
            return Turn 
        else: 
            return False
        
    
    def has_flush(self):
        """Returns True if the hand has a flush, False otherwise.
      
        Note that this works correctly for hands with more than 5 cards.
        """
        self.suit_hist()
        for val in self.suits.values():
            if val >= 5:
                return True
        return False
    
    def has_twopair(self):
        dictb = {}
        counter_string= ''
        for i in self.cards:
            if dicta.get(i.rank,0) > 1: 
                counter_string += ' '
            else: 
                dicta[i.rank] = 1 
        if len(counter_string) == 2: 
            return True 
        else: 
            return False
    
    def three_of_a_kind(self):
        dictb = {}
        for i in self.cards:
            if dictb.get(i.rank,0) > 3: 
                return True 
            else: 
                dictb[i.rank] = 1 
        return False
    
        
    def four_of_a_kind(self): 
        dictb = {}
        counter_string= ''
        for i in self.cards:
            if dicta.get(i.rank,0) > 4: 
                counter_string + ' '
            else: 
                dicta[i.rank] = 1 
        return False
    
    def straight(self): 
        self.sort()
        for i in range(len(self.cards)-5):
            if self.cards[i].rank + 4 == self.cards[i+5].rank: 
                return True 
            else: 
                return False
    
    def straight_flush(self): 
        self.suit_hist()
        for val in self.suits.values():
            if val >= 5:
                return "Flag"
            
        if "Flag" == True: 
            self.sort()
            for i in range(len(self.cards)-5):
                if self.cards[i].rank + 4 == self.cards[i+5].rank: 
                    return True 
                else: 
                    return False 
                
    def full_house(self): 
        return self.three_of_a_kind and self.has_twopair()
            
    def classify(self): 
        print "Classify" 
        if hand.straight_flush() == True:
            print "Straight Flush!"
        if hand.four_of_a_kind() == True:
            print "Four of a Kind!"
#         if hand.full_house() == True:
#             print "Full House!"
        if hand.has_flush() == True:
            print "Flush!"
        if hand.straight() == True:
            print "Straight!"
        if hand.has_twopair() == True:
            print "Two Pair"
        if hand.has_pair() == True:
            print "Pair"
        print "/n"
        
        
        
if __name__ == '__main__':
    # Create a new Deck
    deck = Deck()
    deck.shuffle()

    # Deal the cards and classify the hands. You'll need to add more tests as you create methods
    for i in range(1):
        print "Trial {}:".format(i)
        hand = PokerHand()
        print hand
        print "Has pair?", hand.has_pair() 
        print "Has Two Pair?", hand.has_twopair() 
        print "Has flush?", hand.has_flush() 
        print "Has Three of a Kind?", hand.three_of_a_kind() 
        print "Has Four of a Kind?", hand.four_of_a_kind() 
        print "Has Straight Flush?", hand.straight_flush() 
        print "Has Straight?", hand.straight() 
        print "Has Full House?",hand.full_house()
        deck.move_cards(hand, 7)  
        hand.has_pair()
        # Note: Why aren't we using the deal_hands Deck method you wrote? How could we modify it so that we _could_ use it?
        hand.sort()
        print hand
        print "Contains flush?", hand.has_flush()
        print ''
# Out:
# Trial 0:
#
# Has pair? False
# Has Two Pair? False
# Has flush? False
# Has Three of a Kind? False
# Has Four of a Kind? False
# Has Straight Flush? None
# Has Straight? None
# Has Full House? False
# Ace of Clubs
# 6 of Clubs
# 7 of Clubs
# King of Clubs
# 7 of Diamonds
# 8 of Diamonds
# 10 of Hearts
# Contains flush? False

# %% [markdown]
# ## Quick poll
# About how long did you spend working on this Reading Journal?

# %% [markdown]
#  I spent 3 to 4 hours on this reading journal.

# %% [markdown]
# ## Reading Journal feedback
#
# Have any comments on this Reading Journal? Feel free to leave them below and we'll read them when you submit your journal entry. This could include suggestions to improve the exercises, topics you'd like to see covered in class next time, or other feedback.
#
# If you have Python questions or run into problems while completing the reading, you should post them to Piazza instead so you can get a quick response before your journal is submitted.

# %% [markdown]
# The way the second problem is worded is confusing.
